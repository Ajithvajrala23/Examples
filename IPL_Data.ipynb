# %%
import pandas as pd
import numpy as np

# %%
import yaml

# %%
import yaml

with open("C:\Users\Ajith\Desktop\Data Science\Cricket\ipl/335982.yaml", 'r') as ymlfile:
    cfg1 = yaml.load(ymlfile)
    
with open("C:\Users\Ajith\Desktop\Data Science\Cricket\ipl/1082649.yaml", 'r') as ymlfile:
    cfg2 = yaml.load(ymlfile)
#cfg

# %%
cfg2
# Out:
# {'info': {'city': 'Bangalore',
#   'competition': 'IPL',
#   'dates': [datetime.date(2017, 5, 19)],
#   'gender': 'male',
#   'match_type': 'T20',
#   'outcome': {'by': {'wickets': 6}, 'winner': 'Mumbai Indians'},
#   'overs': 20,
#   'player_of_match': ['KV Sharma'],
#   'teams': ['Mumbai Indians', 'Kolkata Knight Riders'],
#   'toss': {'decision': 'field', 'winner': 'Mumbai Indians'},
#   'umpires': ['NJ Llong', 'Nitin Menon'],
#   'venue': 'M Chinnaswamy Stadium'},
#  'innings': [{'1st innings': {'deliveries': [{0.1: {'batsman': 'CA Lynn',
#        'bowler': 'MG Johnson',
#        'non_striker': 'SP Narine',
#        'runs': {'batsman': 0, 'extras': 0, 'total': 0}}},
#      {0.2: {'batsman': 'CA Lynn',
#        'bowler': 'MG Johnson',
#        'non_striker': 'SP Narine',
#        'runs': {'batsman': 0, 'extras': 0, 'total': 0}}},
#      {0.3: {'batsman': 'CA Lynn',
#        'bowler': 'MG Johnson',
#        'non_striker': 'SP Narine',
# ...

# %%
cfg['info']
# Out:
# {'city': 'Bangalore',
#  'competition': 'IPL',
#  'dates': [datetime.date(2008, 4, 18)],
#  'gender': 'male',
#  'match_type': 'T20',
#  'outcome': {'by': {'runs': 140}, 'winner': 'Kolkata Knight Riders'},
#  'overs': 20,
#  'player_of_match': ['BB McCullum'],
#  'teams': ['Royal Challengers Bangalore', 'Kolkata Knight Riders'],
#  'toss': {'decision': 'field', 'winner': 'Royal Challengers Bangalore'},
#  'umpires': ['Asad Rauf', 'RE Koertzen'],
#  'venue': 'M Chinnaswamy Stadium'}

# %%
df = pd.DataFrame(cfg['info'])
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-12-4b73367d01da> in <module>()
# ----> 1 df = pd.DataFrame(cfg['info'])
#
# C:\Users\Ajith\Anaconda2\lib\site-packages\pandas\core\frame.pyc in __init__(self, data, index, columns, dtype, copy)
#     264                                  dtype=dtype, copy=copy)
#     265         elif isinstance(data, dict):
# --> 266             mgr = self._init_dict(data, index, columns, dtype=dtype)
#     267         elif isinstance(data, ma.MaskedArray):
#     268             import numpy.ma.mrecords as mrecords
#
# C:\Users\Ajith\Anaconda2\lib\site-packages\pandas\core\frame.pyc in _init_dict(self, data, index, columns, dtype)
#     400             arrays = [data[k] for k in keys]
#     401
# --> 402         return _arrays_to_mgr(arrays, data_names, index, columns, dtype=dtype)
#     403
# ...
